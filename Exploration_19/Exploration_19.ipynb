# %% [markdown]
# # Exploration 19 난 스케치를 할 테니 너는 채색을 하거라.
#
# [프로젝트 수행]
# 1. 데이터에 한 가지 이상의 __augmentation 방법__ 을 적용하여 학습하기. (어떠한 방법을 사용했는지 적기)
# 2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 __U-Net Generator를 사용__ 하기
# 3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운받았던 "val" 폴더 내 이미지를 사용
# 4. 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 __스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화__
# 5. 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 __중간 손실 값에 대한 로그__ 를 남기기

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/data/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

# %%
class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i == 0:
                self.blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.blocks.append(EncodeBlock(f))
    
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
Encoder().get_summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encode_block (EncodeBlock)   (None, 128, 128, 64)      3072
# _________________________________________________________________
# encode_block_1 (EncodeBlock) (None, 64, 64, 128)       131584
# _________________________________________________________________
# encode_block_2 (EncodeBlock) (None, 32, 32, 256)       525312
# _________________________________________________________________
# encode_block_3 (EncodeBlock) (None, 16, 16, 512)       2099200
# _________________________________________________________________
# encode_block_4 (EncodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# encode_block_5 (EncodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# encode_block_6 (EncodeBlock) (None, 2, 2, 512)         4196352
# _________________________________________________________________
# encode_block_7 (EncodeBlock) (None, 1, 1, 512)         4196352
# =================================================================
# Total params: 19,544,576
# Trainable params: 19,538,688
# Non-trainable params: 5,888
# _________________________________________________________________

# %%
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

    
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i < 3:
                self.blocks.append(DecodeBlock(f))
            else:
                self.blocks.append(DecodeBlock(f, dropout=False))
                
        self.blocks.append(layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False))
        
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,256)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
Decoder().get_summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1, 1, 256)]       0
# _________________________________________________________________
# decode_block (DecodeBlock)   (None, 2, 2, 512)         2099200
# _________________________________________________________________
# decode_block_1 (DecodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# decode_block_2 (DecodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# decode_block_3 (DecodeBlock) (None, 16, 16, 512)       4196352
# _________________________________________________________________
# decode_block_4 (DecodeBlock) (None, 32, 32, 256)       2098176
# _________________________________________________________________
# decode_block_5 (DecodeBlock) (None, 64, 64, 128)       524800
# _________________________________________________________________
# decode_block_6 (DecodeBlock) (None, 128, 128, 64)      131328
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 256, 256, 3)       3072
# =================================================================
# Total params: 17,445,632
# Trainable params: 17,440,640
# Non-trainable params: 4,992
# _________________________________________________________________

# %%
class EncoderDecoderGenerator(Model):
    def __init__(self):
        super(EncoderDecoderGenerator, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def call(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
   
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        

EncoderDecoderGenerator().get_summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encoder_1 (Encoder)          (None, 1, 1, 512)         19544576
# _________________________________________________________________
# decoder_1 (Decoder)          (None, 256, 256, 3)       19542784
# =================================================================
# Total params: 39,087,360
# Trainable params: 39,076,480
# Non-trainable params: 10,880
# _________________________________________________________________

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_16 (EncodeBlock)   (None, 128, 128, 64) 3072        input_4[0][0]
# __________________________________________________________________________________________________
# encode_block_17 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_16[0][0]
# __________________________________________________________________________________________________
# encode_block_18 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_17[0][0]
# __________________________________________________________________________________________________
# encode_block_19 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_18[0][0]
# __________________________________________________________________________________________________
# encode_block_20 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_19[0][0]
# __________________________________________________________________________________________________
# encode_block_21 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_20[0][0]
# __________________________________________________________________________________________________
# encode_block_22 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_21[0][0]
# __________________________________________________________________________________________________
# encode_block_23 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_14 (DecodeBlock)   (None, 2, 2, 512)    4196352     encode_block_23[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block_14[0][0]
#                                                                  encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_15 (DecodeBlock)   (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_15[0][0]
#                                                                  encode_block_21[0][0]
# __________________________________________________________________________________________________
# decode_block_16 (DecodeBlock)   (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_16[0][0]
#                                                                  encode_block_20[0][0]
# __________________________________________________________________________________________________
# decode_block_17 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_17[0][0]
#                                                                  encode_block_19[0][0]
# __________________________________________________________________________________________________
# decode_block_18 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_18[0][0]
#                                                                  encode_block_18[0][0]
# __________________________________________________________________________________________________
# decode_block_19 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_19[0][0]
#                                                                  encode_block_17[0][0]
# __________________________________________________________________________________________________
# decode_block_20 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_20[0][0]
#                                                                  encode_block_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 20

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:0.9172
# L1_loss:0.3432
# Discriminator_loss:1.5310
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.0846
# L1_loss:0.2859
# Discriminator_loss:0.9911
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.2625
# L1_loss:0.2713
# Discriminator_loss:0.7931
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.6458
# L1_loss:0.2556
# Discriminator_loss:0.6714
#
# EPOCH[1] - STEP[50]
# Generator_loss:2.0667
# L1_loss:0.2259
# Discriminator_loss:0.7131
#
# EPOCH[1] - STEP[60]
# Generator_loss:2.0590
# L1_loss:0.2716
# Discriminator_loss:0.4414
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.3927
# L1_loss:0.2015
# Discriminator_loss:1.5412
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.7768
# L1_loss:0.2374
# Discriminator_loss:0.6105
#
# EPOCH[1] - STEP[90]
# Generator_loss:1.9325
# L1_loss:0.2476
# Discriminator_loss:0.8011
#
# EPOCH[1] - STEP[100]
# Generator_loss:3.0239
# L1_loss:0.2101
# Discriminator_loss:1.2362
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.4794
# L1_loss:0.2840
# Discriminator_loss:0.8227
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.7514
# L1_loss:0.2007
# Discriminator_loss:0.5822
#
# EPOCH[1] - STEP[130]
# Generator_loss:0.9816
# L1_loss:0.2081
# Discriminator_loss:0.6684
#
# EPOCH[1] - STEP[140]
# Generator_loss:1.0720
# L1_loss:0.2972
# Discriminator_loss:0.6183
#
# EPOCH[1] - STEP[150]
# Generator_loss:2.6489
# L1_loss:0.2107
# Discriminator_loss:0.8270
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.3307
# L1_loss:0.2427
# Discriminator_loss:1.1255
#
# EPOCH[1] - STEP[170]
# Generator_loss:1.9766
# L1_loss:0.2213
# Discriminator_loss:1.3972
#
# EPOCH[1] - STEP[180]
# Generator_loss:2.2827
# L1_loss:0.2201
# Discriminator_loss:0.5622
#
# EPOCH[1] - STEP[190]
# Generator_loss:1.0770
# L1_loss:0.2027
# Discriminator_loss:0.8826
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.4897
# L1_loss:0.2144
# Discriminator_loss:0.5034
#
# EPOCH[1] - STEP[210]
# Generator_loss:2.6178
# L1_loss:0.2168
# Discriminator_loss:0.5413
#
# EPOCH[1] - STEP[220]
# Generator_loss:2.0884
# L1_loss:0.2254
# Discriminator_loss:0.6621
#
# EPOCH[1] - STEP[230]
# Generator_loss:0.9474
# L1_loss:0.2142
# Discriminator_loss:0.6845
#
# EPOCH[1] - STEP[240]
# Generator_loss:2.7520
# L1_loss:0.2052
# Discriminator_loss:0.8004
#
# EPOCH[1] - STEP[250]
# Generator_loss:2.3767
# L1_loss:0.2645
# Discriminator_loss:0.5626
#
# EPOCH[2] - STEP[10]
# Generator_loss:0.8939
# L1_loss:0.2260
# Discriminator_loss:1.1807
#
# EPOCH[2] - STEP[20]
# Generator_loss:1.1572
# L1_loss:0.2246
# Discriminator_loss:0.6502
#
# EPOCH[2] - STEP[30]
# Generator_loss:1.8577
# L1_loss:0.2342
# Discriminator_loss:0.9185
#
# EPOCH[2] - STEP[40]
# Generator_loss:2.0586
# L1_loss:0.2395
# Discriminator_loss:0.6779
#
# EPOCH[2] - STEP[50]
# Generator_loss:1.9819
# L1_loss:0.2002
# Discriminator_loss:0.8998
#
# EPOCH[2] - STEP[60]
# Generator_loss:0.6962
# L1_loss:0.2218
# Discriminator_loss:1.0860
#
# EPOCH[2] - STEP[70]
# Generator_loss:1.7563
# L1_loss:0.2225
# Discriminator_loss:0.5894
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.4878
# L1_loss:0.2143
# Discriminator_loss:0.7771
#
# EPOCH[2] - STEP[90]
# Generator_loss:2.0977
# L1_loss:0.1884
# Discriminator_loss:1.0558
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.4413
# L1_loss:0.2021
# Discriminator_loss:0.7650
#
# EPOCH[2] - STEP[110]
# Generator_loss:2.7125
# L1_loss:0.2397
# Discriminator_loss:1.4090
#
# EPOCH[2] - STEP[120]
# Generator_loss:1.8736
# L1_loss:0.1964
# Discriminator_loss:0.5231
#
# EPOCH[2] - STEP[130]
# Generator_loss:1.1654
# L1_loss:0.1909
# Discriminator_loss:0.7989
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.5799
# L1_loss:0.2229
# Discriminator_loss:0.4805
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.6042
# L1_loss:0.2120
# Discriminator_loss:0.7396
#
# EPOCH[2] - STEP[160]
# Generator_loss:0.9005
# L1_loss:0.2513
# Discriminator_loss:0.8751
#
# EPOCH[2] - STEP[170]
# Generator_loss:2.0070
# L1_loss:0.1729
# Discriminator_loss:0.4184
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.5754
# L1_loss:0.2122
# Discriminator_loss:0.4333
#
# EPOCH[2] - STEP[190]
# Generator_loss:2.1594
# L1_loss:0.2493
# Discriminator_loss:0.5710
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.6005
# L1_loss:0.2132
# Discriminator_loss:0.5919
#
# EPOCH[2] - STEP[210]
# Generator_loss:1.1607
# L1_loss:0.1974
# Discriminator_loss:1.3513
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.0768
# L1_loss:0.1910
# Discriminator_loss:1.0522
#
# EPOCH[2] - STEP[230]
# Generator_loss:2.6976
# L1_loss:0.2161
# Discriminator_loss:0.9468
#
# EPOCH[2] - STEP[240]
# Generator_loss:1.3010
# L1_loss:0.2035
# Discriminator_loss:0.7916
#
# EPOCH[2] - STEP[250]
# Generator_loss:2.2658
# L1_loss:0.2091
# Discriminator_loss:0.5272
#
# EPOCH[3] - STEP[10]
# Generator_loss:2.4075
# L1_loss:0.2042
# Discriminator_loss:0.6014
#
# EPOCH[3] - STEP[20]
# Generator_loss:1.8762
# L1_loss:0.2189
# Discriminator_loss:0.4348
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.8758
# L1_loss:0.1625
# Discriminator_loss:0.4275
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.2000
# L1_loss:0.2161
# Discriminator_loss:0.7963
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.4171
# L1_loss:0.2110
# Discriminator_loss:1.1149
#
# EPOCH[3] - STEP[60]
# Generator_loss:1.9053
# L1_loss:0.2214
# Discriminator_loss:0.6214
#
# EPOCH[3] - STEP[70]
# Generator_loss:1.6122
# L1_loss:0.1955
# Discriminator_loss:0.3961
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.1895
# L1_loss:0.2211
# Discriminator_loss:0.8646
#
# EPOCH[3] - STEP[90]
# Generator_loss:1.9163
# L1_loss:0.1833
# Discriminator_loss:0.6199
#
# EPOCH[3] - STEP[100]
# Generator_loss:2.1869
# L1_loss:0.2221
# Discriminator_loss:0.6787
#
# EPOCH[3] - STEP[110]
# Generator_loss:1.7902
# L1_loss:0.1955
# Discriminator_loss:0.8498
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.5061
# L1_loss:0.1705
# Discriminator_loss:0.5899
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.7928
# L1_loss:0.2115
# Discriminator_loss:0.5440
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.3238
# L1_loss:0.2132
# Discriminator_loss:0.8474
#
# EPOCH[3] - STEP[150]
# Generator_loss:1.1101
# L1_loss:0.2207
# Discriminator_loss:0.5872
#
# EPOCH[3] - STEP[160]
# Generator_loss:2.1238
# L1_loss:0.1560
# Discriminator_loss:0.6020
#
# EPOCH[3] - STEP[170]
# Generator_loss:1.6704
# L1_loss:0.1927
# Discriminator_loss:1.0834
#
# EPOCH[3] - STEP[180]
# Generator_loss:0.9058
# L1_loss:0.1636
# Discriminator_loss:0.8074
#
# EPOCH[3] - STEP[190]
# Generator_loss:1.6052
# L1_loss:0.1915
# Discriminator_loss:1.2371
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.7325
# L1_loss:0.2623
# Discriminator_loss:0.8599
#
# EPOCH[3] - STEP[210]
# Generator_loss:1.1182
# L1_loss:0.1769
# Discriminator_loss:0.6661
#
# EPOCH[3] - STEP[220]
# Generator_loss:2.0424
# L1_loss:0.1907
# Discriminator_loss:0.8435
#
# EPOCH[3] - STEP[230]
# Generator_loss:1.8341
# L1_loss:0.1704
# Discriminator_loss:0.6208
#
# EPOCH[3] - STEP[240]
# Generator_loss:0.7170
# L1_loss:0.2575
# Discriminator_loss:1.0504
#
# EPOCH[3] - STEP[250]
# Generator_loss:2.0391
# L1_loss:0.1861
# Discriminator_loss:0.6191
#
# EPOCH[4] - STEP[10]
# Generator_loss:1.8203
# L1_loss:0.2084
# Discriminator_loss:0.7118
#
# EPOCH[4] - STEP[20]
# Generator_loss:2.3792
# L1_loss:0.2337
# Discriminator_loss:0.3371
#
# EPOCH[4] - STEP[30]
# Generator_loss:0.7169
# L1_loss:0.2074
# Discriminator_loss:1.0387
#
# EPOCH[4] - STEP[40]
# Generator_loss:1.2918
# L1_loss:0.1759
# Discriminator_loss:0.7520
#
# EPOCH[4] - STEP[50]
# Generator_loss:0.6990
# L1_loss:0.2108
# Discriminator_loss:0.9702
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.0960
# L1_loss:0.1332
# Discriminator_loss:1.0014
#
# EPOCH[4] - STEP[70]
# Generator_loss:2.5516
# L1_loss:0.2187
# Discriminator_loss:0.5921
#
# EPOCH[4] - STEP[80]
# Generator_loss:2.5095
# L1_loss:0.1969
# Discriminator_loss:0.3798
#
# EPOCH[4] - STEP[90]
# Generator_loss:1.3973
# L1_loss:0.2035
# Discriminator_loss:1.0101
#
# EPOCH[4] - STEP[100]
# Generator_loss:2.4783
# L1_loss:0.1638
# Discriminator_loss:1.0613
#
# EPOCH[4] - STEP[110]
# Generator_loss:2.0650
# L1_loss:0.2141
# Discriminator_loss:1.7657
#
# EPOCH[4] - STEP[120]
# Generator_loss:0.7181
# L1_loss:0.2321
# Discriminator_loss:1.0297
#
# EPOCH[4] - STEP[130]
# Generator_loss:1.3897
# L1_loss:0.1981
# Discriminator_loss:0.6442
#
# EPOCH[4] - STEP[140]
# Generator_loss:1.3113
# L1_loss:0.1836
# Discriminator_loss:0.8201
#
# EPOCH[4] - STEP[150]
# Generator_loss:1.8707
# L1_loss:0.1750
# Discriminator_loss:0.7720
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.4217
# L1_loss:0.1807
# Discriminator_loss:0.8680
#
# EPOCH[4] - STEP[170]
# Generator_loss:1.8134
# L1_loss:0.1974
# Discriminator_loss:0.6674
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.7920
# L1_loss:0.1938
# Discriminator_loss:0.3566
#
# EPOCH[4] - STEP[190]
# Generator_loss:1.7354
# L1_loss:0.1970
# Discriminator_loss:0.4547
#
# EPOCH[4] - STEP[200]
# Generator_loss:0.4352
# L1_loss:0.1660
# Discriminator_loss:1.7851
#
# EPOCH[4] - STEP[210]
# Generator_loss:1.8447
# L1_loss:0.1815
# Discriminator_loss:1.0562
#
# EPOCH[4] - STEP[220]
# Generator_loss:1.2706
# L1_loss:0.1600
# Discriminator_loss:0.7381
#
# EPOCH[4] - STEP[230]
# Generator_loss:1.3440
# L1_loss:0.2149
# Discriminator_loss:0.8258
#
# EPOCH[4] - STEP[240]
# Generator_loss:2.6258
# L1_loss:0.1749
# Discriminator_loss:1.2620
#
# EPOCH[4] - STEP[250]
# Generator_loss:0.3364
# L1_loss:0.2153
# Discriminator_loss:1.8198
#
# EPOCH[5] - STEP[10]
# Generator_loss:1.1232
# L1_loss:0.2041
# Discriminator_loss:0.7851
#
# EPOCH[5] - STEP[20]
# Generator_loss:0.3875
# L1_loss:0.1733
# Discriminator_loss:1.4480
#
# EPOCH[5] - STEP[30]
# Generator_loss:1.9674
# L1_loss:0.2368
# Discriminator_loss:1.0012
#
# EPOCH[5] - STEP[40]
# Generator_loss:1.5238
# L1_loss:0.2400
# Discriminator_loss:0.4330
#
# EPOCH[5] - STEP[50]
# Generator_loss:1.5494
# L1_loss:0.1789
# Discriminator_loss:0.8465
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.2734
# L1_loss:0.1871
# Discriminator_loss:0.8215
#
# EPOCH[5] - STEP[70]
# Generator_loss:1.1807
# L1_loss:0.1840
# Discriminator_loss:0.5724
#
# EPOCH[5] - STEP[80]
# Generator_loss:1.4743
# L1_loss:0.1700
# Discriminator_loss:0.7445
#
# EPOCH[5] - STEP[90]
# Generator_loss:2.2961
# L1_loss:0.1843
# Discriminator_loss:0.9305
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.9732
# L1_loss:0.1869
# Discriminator_loss:0.6065
#
# EPOCH[5] - STEP[110]
# Generator_loss:0.3715
# L1_loss:0.2099
# Discriminator_loss:1.3456
#
# EPOCH[5] - STEP[120]
# Generator_loss:2.0253
# L1_loss:0.1883
# Discriminator_loss:0.6982
#
# EPOCH[5] - STEP[130]
# Generator_loss:0.6085
# L1_loss:0.1846
# Discriminator_loss:1.4000
#
# EPOCH[5] - STEP[140]
# Generator_loss:1.5671
# L1_loss:0.1851
# Discriminator_loss:1.3996
#
# EPOCH[5] - STEP[150]
# Generator_loss:1.3656
# L1_loss:0.1708
# Discriminator_loss:0.8666
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.2045
# L1_loss:0.2151
# Discriminator_loss:0.4870
#
# EPOCH[5] - STEP[170]
# Generator_loss:2.2474
# L1_loss:0.2198
# Discriminator_loss:0.4756
#
# EPOCH[5] - STEP[180]
# Generator_loss:1.9456
# L1_loss:0.1614
# Discriminator_loss:0.7480
#
# EPOCH[5] - STEP[190]
# Generator_loss:3.1623
# L1_loss:0.1731
# Discriminator_loss:2.7342
#
# EPOCH[5] - STEP[200]
# Generator_loss:2.5416
# L1_loss:0.1793
# Discriminator_loss:1.3897
#
# EPOCH[5] - STEP[210]
# Generator_loss:2.1605
# L1_loss:0.1965
# Discriminator_loss:0.7410
#
# EPOCH[5] - STEP[220]
# Generator_loss:2.1175
# L1_loss:0.1914
# Discriminator_loss:0.4156
#
# EPOCH[5] - STEP[230]
# Generator_loss:1.3502
# L1_loss:0.1608
# Discriminator_loss:1.1149
#
# EPOCH[5] - STEP[240]
# Generator_loss:0.9644
# L1_loss:0.1982
# Discriminator_loss:1.3236
#
# EPOCH[5] - STEP[250]
# Generator_loss:2.6504
# L1_loss:0.2045
# Discriminator_loss:0.4814
#
# EPOCH[6] - STEP[10]
# Generator_loss:2.0719
# L1_loss:0.2208
# Discriminator_loss:1.2096
#
# EPOCH[6] - STEP[20]
# Generator_loss:0.3317
# L1_loss:0.1695
# Discriminator_loss:1.5488
#
# EPOCH[6] - STEP[30]
# Generator_loss:0.4553
# L1_loss:0.2197
# Discriminator_loss:1.3808
#
# EPOCH[6] - STEP[40]
# Generator_loss:1.9808
# L1_loss:0.1897
# Discriminator_loss:0.5774
#
# EPOCH[6] - STEP[50]
# Generator_loss:1.1497
# L1_loss:0.1641
# Discriminator_loss:0.6424
#
# EPOCH[6] - STEP[60]
# Generator_loss:2.4343
# L1_loss:0.1458
# Discriminator_loss:1.6260
#
# EPOCH[6] - STEP[70]
# Generator_loss:1.1034
# L1_loss:0.2559
# Discriminator_loss:0.8248
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.8101
# L1_loss:0.2407
# Discriminator_loss:0.8435
#
# EPOCH[6] - STEP[90]
# Generator_loss:1.9561
# L1_loss:0.1613
# Discriminator_loss:0.8723
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.2821
# L1_loss:0.1925
# Discriminator_loss:0.6634
#
# EPOCH[6] - STEP[110]
# Generator_loss:1.4209
# L1_loss:0.1959
# Discriminator_loss:0.8432
#
# EPOCH[6] - STEP[120]
# Generator_loss:1.6676
# L1_loss:0.1569
# Discriminator_loss:0.5359
#
# EPOCH[6] - STEP[130]
# Generator_loss:0.9956
# L1_loss:0.2335
# Discriminator_loss:0.9539
#
# EPOCH[6] - STEP[140]
# Generator_loss:0.6875
# L1_loss:0.1782
# Discriminator_loss:1.0329
#
# EPOCH[6] - STEP[150]
# Generator_loss:2.1892
# L1_loss:0.1987
# Discriminator_loss:0.2723
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.1947
# L1_loss:0.1672
# Discriminator_loss:0.6635
#
# EPOCH[6] - STEP[170]
# Generator_loss:0.8077
# L1_loss:0.2178
# Discriminator_loss:0.8972
#
# EPOCH[6] - STEP[180]
# Generator_loss:2.9579
# L1_loss:0.2080
# Discriminator_loss:1.2182
#
# EPOCH[6] - STEP[190]
# Generator_loss:1.1181
# L1_loss:0.1783
# Discriminator_loss:1.4325
#
# EPOCH[6] - STEP[200]
# Generator_loss:2.1510
# L1_loss:0.1565
# Discriminator_loss:0.8192
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.6309
# L1_loss:0.1709
# Discriminator_loss:0.6497
#
# EPOCH[6] - STEP[220]
# Generator_loss:1.7419
# L1_loss:0.1886
# Discriminator_loss:0.6362
#
# EPOCH[6] - STEP[230]
# Generator_loss:2.8422
# L1_loss:0.1776
# Discriminator_loss:1.4878
#
# EPOCH[6] - STEP[240]
# Generator_loss:1.7108
# L1_loss:0.2241
# Discriminator_loss:0.4649
#
# EPOCH[6] - STEP[250]
# Generator_loss:2.0636
# L1_loss:0.1523
# Discriminator_loss:1.2244
#
# EPOCH[7] - STEP[10]
# Generator_loss:1.4048
# L1_loss:0.1941
# Discriminator_loss:0.4990
#
# EPOCH[7] - STEP[20]
# Generator_loss:2.1326
# L1_loss:0.1760
# Discriminator_loss:1.1977
#
# EPOCH[7] - STEP[30]
# Generator_loss:2.8102
# L1_loss:0.1913
# Discriminator_loss:1.4917
#
# EPOCH[7] - STEP[40]
# Generator_loss:2.8289
# L1_loss:0.1634
# Discriminator_loss:1.8495
#
# EPOCH[7] - STEP[50]
# Generator_loss:2.3228
# L1_loss:0.1569
# Discriminator_loss:1.1626
#
# EPOCH[7] - STEP[60]
# Generator_loss:2.0134
# L1_loss:0.1974
# Discriminator_loss:0.4371
#
# EPOCH[7] - STEP[70]
# Generator_loss:1.2301
# L1_loss:0.1554
# Discriminator_loss:0.9944
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.2516
# L1_loss:0.2202
# Discriminator_loss:0.5196
#
# EPOCH[7] - STEP[90]
# Generator_loss:2.1388
# L1_loss:0.1719
# Discriminator_loss:0.9625
#
# EPOCH[7] - STEP[100]
# Generator_loss:2.1888
# L1_loss:0.1524
# Discriminator_loss:0.7297
#
# EPOCH[7] - STEP[110]
# Generator_loss:1.4776
# L1_loss:0.1823
# Discriminator_loss:0.9655
#
# EPOCH[7] - STEP[120]
# Generator_loss:1.9686
# L1_loss:0.2156
# Discriminator_loss:0.2997
#
# EPOCH[7] - STEP[130]
# Generator_loss:1.1062
# L1_loss:0.1596
# Discriminator_loss:0.6368
#
# EPOCH[7] - STEP[140]
# Generator_loss:2.6328
# L1_loss:0.2413
# Discriminator_loss:0.8195
#
# EPOCH[7] - STEP[150]
# Generator_loss:1.6375
# L1_loss:0.1901
# Discriminator_loss:0.6153
#
# EPOCH[7] - STEP[160]
# Generator_loss:0.5559
# L1_loss:0.1563
# Discriminator_loss:1.4353
#
# EPOCH[7] - STEP[170]
# Generator_loss:2.2358
# L1_loss:0.1735
# Discriminator_loss:0.6433
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.5096
# L1_loss:0.1766
# Discriminator_loss:0.7510
#
# EPOCH[7] - STEP[190]
# Generator_loss:1.3479
# L1_loss:0.1612
# Discriminator_loss:0.8898
#
# EPOCH[7] - STEP[200]
# Generator_loss:0.8217
# L1_loss:0.2195
# Discriminator_loss:0.9888
#
# EPOCH[7] - STEP[210]
# Generator_loss:2.0878
# L1_loss:0.1750
# Discriminator_loss:0.9328
#
# EPOCH[7] - STEP[220]
# Generator_loss:2.4271
# L1_loss:0.2091
# Discriminator_loss:0.3787
#
# EPOCH[7] - STEP[230]
# Generator_loss:1.2083
# L1_loss:0.1664
# Discriminator_loss:0.7412
#
# EPOCH[7] - STEP[240]
# Generator_loss:1.6067
# L1_loss:0.2184
# Discriminator_loss:0.8942
#
# EPOCH[7] - STEP[250]
# Generator_loss:1.2484
# L1_loss:0.2482
# Discriminator_loss:0.5804
#
# EPOCH[8] - STEP[10]
# Generator_loss:1.3679
# L1_loss:0.2048
# Discriminator_loss:0.7450
#
# EPOCH[8] - STEP[20]
# Generator_loss:1.0385
# L1_loss:0.1684
# Discriminator_loss:0.8713
#
# EPOCH[8] - STEP[30]
# Generator_loss:0.3791
# L1_loss:0.1656
# Discriminator_loss:1.3943
#
# EPOCH[8] - STEP[40]
# Generator_loss:2.9553
# L1_loss:0.1442
# Discriminator_loss:1.5783
#
# EPOCH[8] - STEP[50]
# Generator_loss:2.7519
# L1_loss:0.1653
# Discriminator_loss:0.8787
#
# EPOCH[8] - STEP[60]
# Generator_loss:2.1215
# L1_loss:0.1692
# Discriminator_loss:0.8202
#
# EPOCH[8] - STEP[70]
# Generator_loss:2.1280
# L1_loss:0.1905
# Discriminator_loss:1.3031
#
# EPOCH[8] - STEP[80]
# Generator_loss:1.0276
# L1_loss:0.2074
# Discriminator_loss:0.5838
#
# EPOCH[8] - STEP[90]
# Generator_loss:0.8990
# L1_loss:0.1600
# Discriminator_loss:0.7387
#
# EPOCH[8] - STEP[100]
# Generator_loss:1.8668
# L1_loss:0.1695
# Discriminator_loss:1.3023
#
# EPOCH[8] - STEP[110]
# Generator_loss:2.1423
# L1_loss:0.1916
# Discriminator_loss:1.0559
#
# EPOCH[8] - STEP[120]
# Generator_loss:0.9655
# L1_loss:0.1776
# Discriminator_loss:0.6670
#
# EPOCH[8] - STEP[130]
# Generator_loss:1.7170
# L1_loss:0.1626
# Discriminator_loss:0.7245
#
# EPOCH[8] - STEP[140]
# Generator_loss:3.0663
# L1_loss:0.1458
# Discriminator_loss:1.6926
#
# EPOCH[8] - STEP[150]
# Generator_loss:1.4407
# L1_loss:0.2121
# Discriminator_loss:0.9122
#
# EPOCH[8] - STEP[160]
# Generator_loss:1.7621
# L1_loss:0.1782
# Discriminator_loss:0.4337
#
# EPOCH[8] - STEP[170]
# Generator_loss:1.6466
# L1_loss:0.2096
# Discriminator_loss:0.5994
#
# EPOCH[8] - STEP[180]
# Generator_loss:1.8684
# L1_loss:0.1957
# Discriminator_loss:1.4609
#
# EPOCH[8] - STEP[190]
# Generator_loss:1.5507
# L1_loss:0.1761
# Discriminator_loss:0.3852
#
# EPOCH[8] - STEP[200]
# Generator_loss:0.8647
# L1_loss:0.2308
# Discriminator_loss:0.7487
#
# EPOCH[8] - STEP[210]
# Generator_loss:2.4255
# L1_loss:0.1948
# Discriminator_loss:0.2975
#
# EPOCH[8] - STEP[220]
# Generator_loss:1.7612
# L1_loss:0.1815
# Discriminator_loss:0.6786
#
# EPOCH[8] - STEP[230]
# Generator_loss:2.6916
# L1_loss:0.1620
# Discriminator_loss:1.1184
#
# EPOCH[8] - STEP[240]
# Generator_loss:1.9363
# L1_loss:0.1909
# Discriminator_loss:0.6123
#
# EPOCH[8] - STEP[250]
# Generator_loss:2.5196
# L1_loss:0.1795
# Discriminator_loss:0.5342
#
# EPOCH[9] - STEP[10]
# Generator_loss:1.7159
# L1_loss:0.2089
# Discriminator_loss:0.8017
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.7578
# L1_loss:0.1697
# Discriminator_loss:0.6729
#
# EPOCH[9] - STEP[30]
# Generator_loss:3.1163
# L1_loss:0.1597
# Discriminator_loss:2.1528
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.3469
# L1_loss:0.2026
# Discriminator_loss:0.4872
#
# EPOCH[9] - STEP[50]
# Generator_loss:2.4571
# L1_loss:0.2350
# Discriminator_loss:0.4363
#
# EPOCH[9] - STEP[60]
# Generator_loss:2.2000
# L1_loss:0.1996
# Discriminator_loss:0.5638
#
# EPOCH[9] - STEP[70]
# Generator_loss:1.3113
# L1_loss:0.1546
# Discriminator_loss:0.6310
#
# EPOCH[9] - STEP[80]
# Generator_loss:2.2816
# L1_loss:0.2141
# Discriminator_loss:1.2625
#
# EPOCH[9] - STEP[90]
# Generator_loss:1.7398
# L1_loss:0.2194
# Discriminator_loss:0.4401
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.7832
# L1_loss:0.1429
# Discriminator_loss:1.6334
#
# EPOCH[9] - STEP[110]
# Generator_loss:0.6665
# L1_loss:0.2350
# Discriminator_loss:1.0911
#
# EPOCH[9] - STEP[120]
# Generator_loss:2.1225
# L1_loss:0.2282
# Discriminator_loss:0.5311
#
# EPOCH[9] - STEP[130]
# Generator_loss:2.3426
# L1_loss:0.1472
# Discriminator_loss:1.3346
#
# EPOCH[9] - STEP[140]
# Generator_loss:0.7528
# L1_loss:0.2491
# Discriminator_loss:0.9410
#
# EPOCH[9] - STEP[150]
# Generator_loss:3.1427
# L1_loss:0.1928
# Discriminator_loss:1.0778
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.8946
# L1_loss:0.1501
# Discriminator_loss:0.8709
#
# EPOCH[9] - STEP[170]
# Generator_loss:0.5955
# L1_loss:0.1529
# Discriminator_loss:1.2821
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.7898
# L1_loss:0.1674
# Discriminator_loss:0.4349
#
# EPOCH[9] - STEP[190]
# Generator_loss:2.4624
# L1_loss:0.2110
# Discriminator_loss:0.3279
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.0078
# L1_loss:0.1610
# Discriminator_loss:0.6544
#
# EPOCH[9] - STEP[210]
# Generator_loss:1.7447
# L1_loss:0.1818
# Discriminator_loss:0.7180
#
# EPOCH[9] - STEP[220]
# Generator_loss:2.1097
# L1_loss:0.2131
# Discriminator_loss:0.3505
#
# EPOCH[9] - STEP[230]
# Generator_loss:1.6112
# L1_loss:0.1641
# Discriminator_loss:0.4578
#
# EPOCH[9] - STEP[240]
# Generator_loss:2.2167
# L1_loss:0.1804
# Discriminator_loss:0.8727
#
# EPOCH[9] - STEP[250]
# Generator_loss:2.7138
# L1_loss:0.1917
# Discriminator_loss:0.3446
#
# EPOCH[10] - STEP[10]
# Generator_loss:1.4908
# L1_loss:0.1536
# Discriminator_loss:1.7266
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.2651
# L1_loss:0.2376
# Discriminator_loss:0.5187
#
# EPOCH[10] - STEP[30]
# Generator_loss:1.7147
# L1_loss:0.2179
# Discriminator_loss:0.3650
#
# EPOCH[10] - STEP[40]
# Generator_loss:2.4529
# L1_loss:0.1989
# Discriminator_loss:0.3738
#
# EPOCH[10] - STEP[50]
# Generator_loss:1.8305
# L1_loss:0.1560
# Discriminator_loss:0.6652
#
# EPOCH[10] - STEP[60]
# Generator_loss:2.1598
# L1_loss:0.2040
# Discriminator_loss:0.5597
#
# EPOCH[10] - STEP[70]
# Generator_loss:1.2841
# L1_loss:0.1577
# Discriminator_loss:1.0174
#
# EPOCH[10] - STEP[80]
# Generator_loss:0.8414
# L1_loss:0.1653
# Discriminator_loss:0.8547
#
# EPOCH[10] - STEP[90]
# Generator_loss:1.1027
# L1_loss:0.1565
# Discriminator_loss:0.7171
#
# EPOCH[10] - STEP[100]
# Generator_loss:1.0129
# L1_loss:0.1495
# Discriminator_loss:1.0127
#
# EPOCH[10] - STEP[110]
# Generator_loss:1.4799
# L1_loss:0.1872
# Discriminator_loss:0.5343
#
# EPOCH[10] - STEP[120]
# Generator_loss:0.5772
# L1_loss:0.2054
# Discriminator_loss:1.1357
#
# EPOCH[10] - STEP[130]
# Generator_loss:1.5778
# L1_loss:0.2152
# Discriminator_loss:0.6739
#
# EPOCH[10] - STEP[140]
# Generator_loss:1.4521
# L1_loss:0.1789
# Discriminator_loss:0.3845
#
# EPOCH[10] - STEP[150]
# Generator_loss:2.5111
# L1_loss:0.1373
# Discriminator_loss:2.2755
#
# EPOCH[10] - STEP[160]
# Generator_loss:2.2316
# L1_loss:0.2094
# Discriminator_loss:0.3179
#
# EPOCH[10] - STEP[170]
# Generator_loss:2.3582
# L1_loss:0.2164
# Discriminator_loss:0.1889
#
# EPOCH[10] - STEP[180]
# Generator_loss:2.5158
# L1_loss:0.1560
# Discriminator_loss:0.4984
#
# EPOCH[10] - STEP[190]
# Generator_loss:0.1545
# L1_loss:0.1897
# Discriminator_loss:2.4251
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.6937
# L1_loss:0.1633
# Discriminator_loss:1.2883
#
# EPOCH[10] - STEP[210]
# Generator_loss:2.2629
# L1_loss:0.1538
# Discriminator_loss:1.7720
#
# EPOCH[10] - STEP[220]
# Generator_loss:0.7245
# L1_loss:0.2093
# Discriminator_loss:1.0341
#
# EPOCH[10] - STEP[230]
# Generator_loss:2.0649
# L1_loss:0.1760
# Discriminator_loss:0.4054
#
# EPOCH[10] - STEP[240]
# Generator_loss:1.0925
# L1_loss:0.1975
# Discriminator_loss:0.6844
#
# EPOCH[10] - STEP[250]
# Generator_loss:1.9524
# L1_loss:0.1877
# Discriminator_loss:0.6384
#
# EPOCH[11] - STEP[10]
# Generator_loss:0.1686
# L1_loss:0.1877
# Discriminator_loss:2.3493
#
# EPOCH[11] - STEP[20]
# Generator_loss:1.1214
# L1_loss:0.1754
# Discriminator_loss:0.7007
#
# EPOCH[11] - STEP[30]
# Generator_loss:1.9558
# L1_loss:0.1536
# Discriminator_loss:0.4159
#
# EPOCH[11] - STEP[40]
# Generator_loss:1.8796
# L1_loss:0.1608
# Discriminator_loss:0.4992
#
# EPOCH[11] - STEP[50]
# Generator_loss:1.7108
# L1_loss:0.2486
# Discriminator_loss:0.6102
#
# EPOCH[11] - STEP[60]
# Generator_loss:2.6440
# L1_loss:0.1731
# Discriminator_loss:0.7133
#
# EPOCH[11] - STEP[70]
# Generator_loss:0.8695
# L1_loss:0.2424
# Discriminator_loss:0.7884
#
# EPOCH[11] - STEP[80]
# Generator_loss:1.1205
# L1_loss:0.2045
# Discriminator_loss:0.5471
#
# EPOCH[11] - STEP[90]
# Generator_loss:1.6538
# L1_loss:0.1951
# Discriminator_loss:0.7528
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.5823
# L1_loss:0.2062
# Discriminator_loss:0.7106
#
# EPOCH[11] - STEP[110]
# Generator_loss:1.0523
# L1_loss:0.1775
# Discriminator_loss:0.8788
#
# EPOCH[11] - STEP[120]
# Generator_loss:1.1795
# L1_loss:0.1742
# Discriminator_loss:0.7581
#
# EPOCH[11] - STEP[130]
# Generator_loss:2.1661
# L1_loss:0.1426
# Discriminator_loss:1.0279
#
# EPOCH[11] - STEP[140]
# Generator_loss:2.5476
# L1_loss:0.2082
# Discriminator_loss:1.2530
#
# EPOCH[11] - STEP[150]
# Generator_loss:2.2696
# L1_loss:0.2091
# Discriminator_loss:0.4047
#
# EPOCH[11] - STEP[160]
# Generator_loss:1.4056
# L1_loss:0.1576
# Discriminator_loss:0.8215
#
# EPOCH[11] - STEP[170]
# Generator_loss:1.6430
# L1_loss:0.1784
# Discriminator_loss:0.3811
#
# EPOCH[11] - STEP[180]
# Generator_loss:2.6044
# L1_loss:0.1740
# Discriminator_loss:0.7760
#
# EPOCH[11] - STEP[190]
# Generator_loss:1.5228
# L1_loss:0.1597
# Discriminator_loss:0.4520
#
# EPOCH[11] - STEP[200]
# Generator_loss:0.8065
# L1_loss:0.1792
# Discriminator_loss:0.8992
#
# EPOCH[11] - STEP[210]
# Generator_loss:2.2129
# L1_loss:0.1863
# Discriminator_loss:0.3285
#
# EPOCH[11] - STEP[220]
# Generator_loss:2.3533
# L1_loss:0.1417
# Discriminator_loss:0.6541
#
# EPOCH[11] - STEP[230]
# Generator_loss:1.3136
# L1_loss:0.1665
# Discriminator_loss:1.0055
#
# EPOCH[11] - STEP[240]
# Generator_loss:2.2743
# L1_loss:0.1699
# Discriminator_loss:1.0303
#
# EPOCH[11] - STEP[250]
# Generator_loss:1.6574
# L1_loss:0.1558
# Discriminator_loss:1.2493
#
# EPOCH[12] - STEP[10]
# Generator_loss:1.0454
# L1_loss:0.1723
# Discriminator_loss:0.6813
#
# EPOCH[12] - STEP[20]
# Generator_loss:2.1459
# L1_loss:0.1999
# Discriminator_loss:0.4757
#
# EPOCH[12] - STEP[30]
# Generator_loss:0.2865
# L1_loss:0.1475
# Discriminator_loss:1.8304
#
# EPOCH[12] - STEP[40]
# Generator_loss:2.1467
# L1_loss:0.2077
# Discriminator_loss:0.4535
#
# EPOCH[12] - STEP[50]
# Generator_loss:2.6375
# L1_loss:0.1631
# Discriminator_loss:1.1670
#
# EPOCH[12] - STEP[60]
# Generator_loss:2.8114
# L1_loss:0.1928
# Discriminator_loss:0.7008
#
# EPOCH[12] - STEP[70]
# Generator_loss:1.9440
# L1_loss:0.1515
# Discriminator_loss:0.4363
#
# EPOCH[12] - STEP[80]
# Generator_loss:1.3873
# L1_loss:0.1619
# Discriminator_loss:0.7746
#
# EPOCH[12] - STEP[90]
# Generator_loss:2.4583
# L1_loss:0.1440
# Discriminator_loss:1.7056
#
# EPOCH[12] - STEP[100]
# Generator_loss:1.6580
# L1_loss:0.1406
# Discriminator_loss:0.8760
#
# EPOCH[12] - STEP[110]
# Generator_loss:0.5382
# L1_loss:0.1991
# Discriminator_loss:1.0447
#
# EPOCH[12] - STEP[120]
# Generator_loss:1.0574
# L1_loss:0.1839
# Discriminator_loss:0.8174
#
# EPOCH[12] - STEP[130]
# Generator_loss:2.4152
# L1_loss:0.1739
# Discriminator_loss:0.6519
#
# EPOCH[12] - STEP[140]
# Generator_loss:1.3241
# L1_loss:0.1757
# Discriminator_loss:1.1606
#
# EPOCH[12] - STEP[150]
# Generator_loss:2.1596
# L1_loss:0.1526
# Discriminator_loss:1.5591
#
# EPOCH[12] - STEP[160]
# Generator_loss:1.2943
# L1_loss:0.2496
# Discriminator_loss:0.5929
#
# EPOCH[12] - STEP[170]
# Generator_loss:1.8405
# L1_loss:0.1552
# Discriminator_loss:0.9246
#
# EPOCH[12] - STEP[180]
# Generator_loss:1.1425
# L1_loss:0.2469
# Discriminator_loss:0.6914
#
# EPOCH[12] - STEP[190]
# Generator_loss:1.2844
# L1_loss:0.1699
# Discriminator_loss:0.6063
#
# EPOCH[12] - STEP[200]
# Generator_loss:2.5263
# L1_loss:0.1891
# Discriminator_loss:1.3719
#
# EPOCH[12] - STEP[210]
# Generator_loss:1.6266
# L1_loss:0.1843
# Discriminator_loss:0.4091
#
# EPOCH[12] - STEP[220]
# Generator_loss:1.7625
# L1_loss:0.1626
# Discriminator_loss:1.1065
#
# EPOCH[12] - STEP[230]
# Generator_loss:1.1912
# L1_loss:0.1790
# Discriminator_loss:0.7532
#
# EPOCH[12] - STEP[240]
# Generator_loss:3.5732
# L1_loss:0.1755
# Discriminator_loss:0.3397
#
# EPOCH[12] - STEP[250]
# Generator_loss:2.2219
# L1_loss:0.1928
# Discriminator_loss:0.4411
#
# EPOCH[13] - STEP[10]
# Generator_loss:1.4822
# L1_loss:0.1857
# Discriminator_loss:0.4017
#
# EPOCH[13] - STEP[20]
# Generator_loss:0.3068
# L1_loss:0.1751
# Discriminator_loss:1.7644
#
# EPOCH[13] - STEP[30]
# Generator_loss:1.8027
# L1_loss:0.1437
# Discriminator_loss:0.7122
#
# EPOCH[13] - STEP[40]
# Generator_loss:3.2095
# L1_loss:0.1822
# Discriminator_loss:2.2187
#
# EPOCH[13] - STEP[50]
# Generator_loss:0.3163
# L1_loss:0.1984
# Discriminator_loss:1.5630
#
# EPOCH[13] - STEP[60]
# Generator_loss:0.7341
# L1_loss:0.1633
# Discriminator_loss:1.1910
#
# EPOCH[13] - STEP[70]
# Generator_loss:1.8805
# L1_loss:0.2097
# Discriminator_loss:0.3849
#
# EPOCH[13] - STEP[80]
# Generator_loss:2.6747
# L1_loss:0.1529
# Discriminator_loss:0.5639
#
# EPOCH[13] - STEP[90]
# Generator_loss:1.1107
# L1_loss:0.1982
# Discriminator_loss:0.9573
#
# EPOCH[13] - STEP[100]
# Generator_loss:0.5595
# L1_loss:0.1576
# Discriminator_loss:1.0812
#
# EPOCH[13] - STEP[110]
# Generator_loss:1.8108
# L1_loss:0.1966
# Discriminator_loss:1.5082
#
# EPOCH[13] - STEP[120]
# Generator_loss:2.0882
# L1_loss:0.2296
# Discriminator_loss:0.7685
#
# EPOCH[13] - STEP[130]
# Generator_loss:0.2496
# L1_loss:0.2393
# Discriminator_loss:1.9061
#
# EPOCH[13] - STEP[140]
# Generator_loss:1.1018
# L1_loss:0.2119
# Discriminator_loss:0.6819
#
# EPOCH[13] - STEP[150]
# Generator_loss:0.9010
# L1_loss:0.1635
# Discriminator_loss:0.9274
#
# EPOCH[13] - STEP[160]
# Generator_loss:1.6115
# L1_loss:0.2149
# Discriminator_loss:0.6365
#
# EPOCH[13] - STEP[170]
# Generator_loss:1.5451
# L1_loss:0.1675
# Discriminator_loss:0.4777
#
# EPOCH[13] - STEP[180]
# Generator_loss:1.7324
# L1_loss:0.1734
# Discriminator_loss:0.9212
#
# EPOCH[13] - STEP[190]
# Generator_loss:2.4881
# L1_loss:0.1577
# Discriminator_loss:0.7059
#
# EPOCH[13] - STEP[200]
# Generator_loss:1.6681
# L1_loss:0.1322
# Discriminator_loss:1.5269
#
# EPOCH[13] - STEP[210]
# Generator_loss:1.5994
# L1_loss:0.1475
# Discriminator_loss:0.6614
#
# EPOCH[13] - STEP[220]
# Generator_loss:0.9742
# L1_loss:0.1484
# Discriminator_loss:1.2266
#
# EPOCH[13] - STEP[230]
# Generator_loss:0.7457
# L1_loss:0.1587
# Discriminator_loss:0.8859
#
# EPOCH[13] - STEP[240]
# Generator_loss:2.1977
# L1_loss:0.1451
# Discriminator_loss:1.2049
#
# EPOCH[13] - STEP[250]
# ...
# L1_loss:0.1674
# Discriminator_loss:0.4770
#
# EPOCH[16] - STEP[190]
# Generator_loss:3.0002
# L1_loss:0.1650
# Discriminator_loss:0.5859
#
# EPOCH[16] - STEP[200]
# Generator_loss:2.1151
# L1_loss:0.1504
# Discriminator_loss:0.2576
#
# EPOCH[16] - STEP[210]
# Generator_loss:1.0797
# L1_loss:0.1889
# Discriminator_loss:0.6269
#
# EPOCH[16] - STEP[220]
# Generator_loss:1.0689
# L1_loss:0.2175
# Discriminator_loss:0.5082
#
# EPOCH[16] - STEP[230]
# Generator_loss:2.2212
# L1_loss:0.1828
# Discriminator_loss:0.5716
#
# EPOCH[16] - STEP[240]
# Generator_loss:1.3904
# L1_loss:0.1834
# Discriminator_loss:0.7237
#
# EPOCH[16] - STEP[250]
# Generator_loss:0.8562
# L1_loss:0.1478
# Discriminator_loss:0.8455
#
# EPOCH[17] - STEP[10]
# Generator_loss:1.4354
# L1_loss:0.1370
# Discriminator_loss:0.5653
#
# EPOCH[17] - STEP[20]
# Generator_loss:1.9102
# L1_loss:0.1372
# Discriminator_loss:0.3031
#
# EPOCH[17] - STEP[30]
# Generator_loss:2.0885
# L1_loss:0.1445
# Discriminator_loss:0.6023
#
# EPOCH[17] - STEP[40]
# Generator_loss:2.0905
# L1_loss:0.1832
# Discriminator_loss:0.4525
#
# EPOCH[17] - STEP[50]
# Generator_loss:2.3487
# L1_loss:0.1305
# Discriminator_loss:0.5268
#
# EPOCH[17] - STEP[60]
# Generator_loss:1.3272
# L1_loss:0.1380
# Discriminator_loss:1.3709
#
# EPOCH[17] - STEP[70]
# Generator_loss:2.9382
# L1_loss:0.1421
# Discriminator_loss:1.0438
#
# EPOCH[17] - STEP[80]
# Generator_loss:1.9020
# L1_loss:0.1441
# Discriminator_loss:0.3865
#
# EPOCH[17] - STEP[90]
# Generator_loss:0.4118
# L1_loss:0.1922
# Discriminator_loss:1.4709
#
# EPOCH[17] - STEP[100]
# Generator_loss:0.8371
# L1_loss:0.1761
# Discriminator_loss:0.7939
#
# EPOCH[17] - STEP[110]
# Generator_loss:0.4861
# L1_loss:0.1370
# Discriminator_loss:1.2320
#
# EPOCH[17] - STEP[120]
# Generator_loss:0.7256
# L1_loss:0.1610
# Discriminator_loss:0.9015
#
# EPOCH[17] - STEP[130]
# Generator_loss:1.8972
# L1_loss:0.1475
# Discriminator_loss:0.4413
#
# EPOCH[17] - STEP[140]
# Generator_loss:1.9114
# L1_loss:0.1960
# Discriminator_loss:0.5175
#
# EPOCH[17] - STEP[150]
# Generator_loss:0.3377
# L1_loss:0.1796
# Discriminator_loss:1.6501
#
# EPOCH[17] - STEP[160]
# Generator_loss:1.5462
# L1_loss:0.1952
# Discriminator_loss:0.4207
#
# EPOCH[17] - STEP[170]
# Generator_loss:0.7451
# L1_loss:0.1576
# Discriminator_loss:0.8563
#
# EPOCH[17] - STEP[180]
# Generator_loss:3.6395
# L1_loss:0.1469
# Discriminator_loss:0.4366
#
# EPOCH[17] - STEP[190]
# Generator_loss:1.5291
# L1_loss:0.1792
# Discriminator_loss:0.5294
#
# EPOCH[17] - STEP[200]
# Generator_loss:0.9806
# L1_loss:0.1532
# Discriminator_loss:0.6498
#
# EPOCH[17] - STEP[210]
# Generator_loss:1.0634
# L1_loss:0.1453
# Discriminator_loss:1.4115
#
# EPOCH[17] - STEP[220]
# Generator_loss:1.5484
# L1_loss:0.1585
# Discriminator_loss:0.5252
#
# EPOCH[17] - STEP[230]
# Generator_loss:3.9164
# L1_loss:0.1347
# Discriminator_loss:2.4015
#
# EPOCH[17] - STEP[240]
# Generator_loss:0.8320
# L1_loss:0.1329
# Discriminator_loss:1.3638
#
# EPOCH[17] - STEP[250]
# Generator_loss:0.8270
# L1_loss:0.1654
# Discriminator_loss:0.8543
#
# EPOCH[18] - STEP[10]
# Generator_loss:1.5257
# L1_loss:0.1913
# Discriminator_loss:0.4427
#
# EPOCH[18] - STEP[20]
# Generator_loss:2.3655
# L1_loss:0.1365
# Discriminator_loss:1.0265
#
# EPOCH[18] - STEP[30]
# Generator_loss:2.6852
# L1_loss:0.1445
# Discriminator_loss:1.6968
#
# EPOCH[18] - STEP[40]
# Generator_loss:1.6001
# L1_loss:0.2014
# Discriminator_loss:0.3299
#
# EPOCH[18] - STEP[50]
# Generator_loss:2.1408
# L1_loss:0.1344
# Discriminator_loss:1.5986
#
# EPOCH[18] - STEP[60]
# Generator_loss:0.2166
# L1_loss:0.1807
# Discriminator_loss:1.9317
#
# EPOCH[18] - STEP[70]
# Generator_loss:1.2216
# L1_loss:0.1664
# Discriminator_loss:0.6536
#
# EPOCH[18] - STEP[80]
# Generator_loss:1.2803
# L1_loss:0.1635
# Discriminator_loss:0.5697
#
# EPOCH[18] - STEP[90]
# Generator_loss:2.2356
# L1_loss:0.1661
# Discriminator_loss:0.4657
#
# EPOCH[18] - STEP[100]
# Generator_loss:2.3793
# L1_loss:0.1826
# Discriminator_loss:0.5138
#
# EPOCH[18] - STEP[110]
# Generator_loss:1.7308
# L1_loss:0.2178
# Discriminator_loss:0.4122
#
# EPOCH[18] - STEP[120]
# Generator_loss:1.3636
# L1_loss:0.1372
# Discriminator_loss:0.8098
#
# EPOCH[18] - STEP[130]
# Generator_loss:3.9479
# L1_loss:0.1446
# Discriminator_loss:1.2520
#
# EPOCH[18] - STEP[140]
# Generator_loss:1.5559
# L1_loss:0.1860
# Discriminator_loss:1.0295
#
# EPOCH[18] - STEP[150]
# Generator_loss:1.3652
# L1_loss:0.1523
# Discriminator_loss:0.6264
#
# EPOCH[18] - STEP[160]
# Generator_loss:1.9494
# L1_loss:0.2036
# Discriminator_loss:0.2538
#
# EPOCH[18] - STEP[170]
# Generator_loss:1.3654
# L1_loss:0.2181
# Discriminator_loss:0.5451
#
# EPOCH[18] - STEP[180]
# Generator_loss:0.7111
# L1_loss:0.1893
# Discriminator_loss:0.8633
#
# EPOCH[18] - STEP[190]
# Generator_loss:0.6324
# L1_loss:0.1633
# Discriminator_loss:0.9667
#
# EPOCH[18] - STEP[200]
# Generator_loss:1.6007
# L1_loss:0.1689
# Discriminator_loss:0.5036
#
# EPOCH[18] - STEP[210]
# Generator_loss:0.6419
# L1_loss:0.1590
# Discriminator_loss:1.2666
#
# EPOCH[18] - STEP[220]
# Generator_loss:2.8541
# L1_loss:0.1378
# Discriminator_loss:1.1512
#
# EPOCH[18] - STEP[230]
# Generator_loss:0.6616
# L1_loss:0.1258
# Discriminator_loss:1.0147
#
# EPOCH[18] - STEP[240]
# Generator_loss:3.3509
# L1_loss:0.1690
# Discriminator_loss:0.3511
#
# EPOCH[18] - STEP[250]
# Generator_loss:2.4167
# L1_loss:0.1486
# Discriminator_loss:2.4462
#
# EPOCH[19] - STEP[10]
# Generator_loss:2.0091
# L1_loss:0.1635
# Discriminator_loss:0.5084
#
# EPOCH[19] - STEP[20]
# Generator_loss:2.7790
# L1_loss:0.1487
# Discriminator_loss:0.3093
#
# EPOCH[19] - STEP[30]
# Generator_loss:1.8858
# L1_loss:0.1418
# Discriminator_loss:0.3448
#
# EPOCH[19] - STEP[40]
# Generator_loss:3.3805
# L1_loss:0.1664
# Discriminator_loss:1.4820
#
# EPOCH[19] - STEP[50]
# Generator_loss:2.4318
# L1_loss:0.1670
# Discriminator_loss:0.3695
#
# EPOCH[19] - STEP[60]
# Generator_loss:1.6214
# L1_loss:0.1497
# Discriminator_loss:0.4571
#
# EPOCH[19] - STEP[70]
# Generator_loss:1.5113
# L1_loss:0.1740
# Discriminator_loss:0.5672
#
# EPOCH[19] - STEP[80]
# Generator_loss:2.3674
# L1_loss:0.1728
# Discriminator_loss:0.5172
#
# EPOCH[19] - STEP[90]
# Generator_loss:0.5489
# L1_loss:0.1847
# Discriminator_loss:1.3039
#
# EPOCH[19] - STEP[100]
# Generator_loss:2.3893
# L1_loss:0.1940
# Discriminator_loss:0.3694
#
# EPOCH[19] - STEP[110]
# Generator_loss:0.8451
# L1_loss:0.1844
# Discriminator_loss:0.7930
#
# EPOCH[19] - STEP[120]
# Generator_loss:1.9669
# L1_loss:0.1485
# Discriminator_loss:0.4582
#
# EPOCH[19] - STEP[130]
# Generator_loss:0.5769
# L1_loss:0.1514
# Discriminator_loss:1.1640
#
# EPOCH[19] - STEP[140]
# Generator_loss:2.5715
# L1_loss:0.1421
# Discriminator_loss:0.2304
#
# EPOCH[19] - STEP[150]
# Generator_loss:1.2592
# L1_loss:0.1820
# Discriminator_loss:0.6861
#
# EPOCH[19] - STEP[160]
# Generator_loss:1.3895
# L1_loss:0.1345
# Discriminator_loss:0.5898
#
# EPOCH[19] - STEP[170]
# Generator_loss:1.8475
# L1_loss:0.1444
# Discriminator_loss:0.3138
#
# EPOCH[19] - STEP[180]
# Generator_loss:2.8518
# L1_loss:0.1408
# Discriminator_loss:0.5245
#
# EPOCH[19] - STEP[190]
# Generator_loss:0.9085
# L1_loss:0.1633
# Discriminator_loss:0.7878
#
# EPOCH[19] - STEP[200]
# Generator_loss:2.2088
# L1_loss:0.1384
# Discriminator_loss:0.5059
#
# EPOCH[19] - STEP[210]
# Generator_loss:2.7525
# L1_loss:0.1552
# Discriminator_loss:0.8822
#
# EPOCH[19] - STEP[220]
# Generator_loss:1.1426
# L1_loss:0.1295
# Discriminator_loss:0.9428
#
# EPOCH[19] - STEP[230]
# Generator_loss:1.5973
# L1_loss:0.1798
# Discriminator_loss:0.5866
#
# EPOCH[19] - STEP[240]
# Generator_loss:1.2542
# L1_loss:0.1575
# Discriminator_loss:0.4813
#
# EPOCH[19] - STEP[250]
# Generator_loss:1.5126
# L1_loss:0.1391
# Discriminator_loss:0.7260
#
# EPOCH[20] - STEP[10]
# Generator_loss:2.5116
# L1_loss:0.1733
# Discriminator_loss:1.3608
#
# EPOCH[20] - STEP[20]
# Generator_loss:3.2361
# L1_loss:0.1812
# Discriminator_loss:0.2847
#
# EPOCH[20] - STEP[30]
# Generator_loss:1.2076
# L1_loss:0.1954
# Discriminator_loss:0.8714
#
# EPOCH[20] - STEP[40]
# Generator_loss:1.8656
# L1_loss:0.1427
# Discriminator_loss:0.3036
#
# EPOCH[20] - STEP[50]
# Generator_loss:0.8537
# L1_loss:0.1519
# Discriminator_loss:1.0833
#
# EPOCH[20] - STEP[60]
# Generator_loss:1.3527
# L1_loss:0.1376
# Discriminator_loss:0.6925
#
# EPOCH[20] - STEP[70]
# Generator_loss:2.5383
# L1_loss:0.1333
# Discriminator_loss:0.5377
#
# EPOCH[20] - STEP[80]
# Generator_loss:1.5210
# L1_loss:0.1509
# Discriminator_loss:0.4637
#
# EPOCH[20] - STEP[90]
# Generator_loss:1.8368
# L1_loss:0.1911
# Discriminator_loss:0.3737
#
# EPOCH[20] - STEP[100]
# Generator_loss:0.9057
# L1_loss:0.1682
# Discriminator_loss:0.9390
#
# EPOCH[20] - STEP[110]
# Generator_loss:2.2123
# L1_loss:0.1569
# Discriminator_loss:1.0848
#
# EPOCH[20] - STEP[120]
# Generator_loss:2.9282
# L1_loss:0.2095
# Discriminator_loss:0.4176
#
# EPOCH[20] - STEP[130]
# Generator_loss:2.6315
# L1_loss:0.1488
# Discriminator_loss:1.0449
#
# EPOCH[20] - STEP[140]
# Generator_loss:1.5500
# L1_loss:0.1481
# Discriminator_loss:0.6248
#
# EPOCH[20] - STEP[150]
# Generator_loss:2.0981
# L1_loss:0.1570
# Discriminator_loss:0.7352
#
# EPOCH[20] - STEP[160]
# Generator_loss:1.7170
# L1_loss:0.1537
# Discriminator_loss:0.6043
#
# EPOCH[20] - STEP[170]
# Generator_loss:1.4068
# L1_loss:0.1405
# Discriminator_loss:1.0740
#
# EPOCH[20] - STEP[180]
# Generator_loss:1.0072
# L1_loss:0.1695
# Discriminator_loss:0.6427
#
# EPOCH[20] - STEP[190]
# Generator_loss:0.5707
# L1_loss:0.1559
# Discriminator_loss:1.1539
#
# EPOCH[20] - STEP[200]
# Generator_loss:1.4755
# L1_loss:0.1466
# Discriminator_loss:0.5937
#
# EPOCH[20] - STEP[210]
# Generator_loss:1.8109
# L1_loss:0.1439
# Discriminator_loss:0.7034
#
# EPOCH[20] - STEP[220]
# Generator_loss:2.7715
# L1_loss:0.1495
# Discriminator_loss:0.9191
#
# EPOCH[20] - STEP[230]
# Generator_loss:2.9459
# L1_loss:0.1977
# Discriminator_loss:0.9201
#
# EPOCH[20] - STEP[240]
# Generator_loss:0.4634
# L1_loss:0.1399
# Discriminator_loss:1.3151
#
# EPOCH[20] - STEP[250]
# Generator_loss:1.2499
# L1_loss:0.1557
# Discriminator_loss:0.6532

# %%
test_ind = 5

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))
